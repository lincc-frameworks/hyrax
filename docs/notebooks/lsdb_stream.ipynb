# %% [markdown]
# # Example notebook for streaming from lsdb

# %%
class MyLSDBStream:
    pass

# %%
from hyrax import Hyrax
h = Hyrax()

# Probably want loopback model
h.set_config("model.name", "HyraxLoopback")

data_request_definition = {
    "train": {
        "data": {
            "data_stream_class":"MyLSDBStream",
            "dataset_class": "LSDBStreamDataset",
            "data_location": "./data",
            "fields": ["ra", "dec"],
            "primary_id_field": "object_id",
            "split_fraction": 1.0,
        },
    },
}

h.set_config("data_request", data_request_definition)
